# %% [markdown]
# # Lesson 1 — How does the robot know what to do?
#
# ---
#
# ## 🎬 Watch first — then do
#
# **Before touching anything, watch the video below.**
# It shows you exactly what you will do in this lesson.
#
# <div style="padding:56.25% 0 0 0;position:relative;">
#   <iframe src="https://player.vimeo.com/video/YOUR_VIDEO_ID"
#           style="position:absolute;top:0;left:0;width:100%;height:100%;"
#           frameborder="0" allow="autoplay; fullscreen; picture-in-picture" allowfullscreen>
#   </iframe>
# </div>
#
# ---

# %% [markdown]
# ## 🚀 Now do it yourself
#
# You just watched it. Now reproduce it exactly.
#
# **Step 1 — Open your desktop**
#
# Click on the cell below then press **Shift+Enter** to run it. A button will appear.

# %%
import os
from urllib.parse import quote
from IPython.display import HTML, display

user = os.environ.get('JUPYTERHUB_USER', 'user')
desktop_url = f'https://app.rosforge.com/user/{quote(user, safe="")}/proxy/6080/'

display(HTML(f'''
<div style="text-align:center;margin:20px 0;">
  <a href="{desktop_url}" target="_blank"
     style="background:#00D4FF;color:#000;padding:20px 60px;text-decoration:none;
            border-radius:8px;font-size:20px;font-weight:700;display:inline-block;">
    🖥️ Open Desktop
  </a>
</div>
'''))
# Out:
# <div style="text-align:center;margin:20px 0;">
#   <a href="https://app.rosforge.com/user/github%3Aurllib2/proxy/6080/" target="_blank"
#      style="background:#00D4FF;color:#000;padding:20px 60px;text-decoration:none;
#             border-radius:8px;font-size:20px;font-weight:700;display:inline-block;">
#     🖥️ Open Desktop
#   </a>
# </div>

# %% [markdown]
# **Step 2 — Open Terminator**
#
# Inside the desktop: right-click anywhere on the black background → select **Terminator**
#
# ---
#
# **Step 3 — Start the robot**
#
# In Terminator, type:
#
# ```bash
# bash ~/course_materials/scripts/start_robot.sh
# ```
#
# Wait 5 seconds. RViz opens automatically. Your robot appears in 3D.
#
# ---
#
# **Step 4 — Open a second terminal**
#
# The first terminal is busy running the robot. You need a second one.
#
# Inside Terminator: right-click → **Split Horizontally**
#
# ---
#
# **Step 5 — Drive the robot**
#
# In the new bottom terminal:
#
# ```bash
# ros2 topic pub /cmd_vel geometry_msgs/msg/Twist "{linear: {x: 0.5}, angular: {z: 0.5}}"
# ```
#
# The robot moves in RViz. Watch it.
#
#
# ---

# %% [markdown]
# ---
#
# ## 🔍 Explore — before we explain anything
#
# The robot is running. Open a second terminal and run:
#
# ```bash
# ros2 node list
# ```
#
# You will see all the programs currently running. Each one is a **node**.
#
# Now run:
#
# ```bash
# rqt_graph
# ```
#
# You will see the same nodes — but this time as a visual graph. Every circle is a node, every arrow is a topic.
#
# **This is what your rqt_graph should look like:**
#
# ![rqt_graph](images/rqt_graph_lesson1.png)
#
# Now run this:
#
# ```bash
# ros2 topic info /cmd_vel
# ```
#
# You will see exactly who is publishing on `/cmd_vel` and who is subscribing to it.
#
# ---

# %% [markdown]
# ## 🧠 Challenge 1 — Something unexpected
#
# The robot is moving and you can see its node in `rqt_graph`.
#
# Now press **Ctrl+C** to stop the `cmd_vel` publisher. Then run `rqt_graph` again.
#
# **Observe:**
# 1. What disappeared from the graph?
# 2. The robot is still moving — but the publisher node is gone. How is that possible?
#
# Write your best explanation before reading on.

# %% [markdown]
# *Write your explanation here:*
#
# **What disappeared:**
#
# **Why the robot is still moving even though the publisher is gone:**

# %% [markdown]
# ---
#
# ## 💡 What just happened — the explanation
#
# ### Nodes
#
# In ROS2, each independent program is called a **node**. The robot simulator is a node. `robot_state_publisher` is a node. RViz is a node. The `cmd_vel` command you typed created a temporary node.
#
# You saw all of them in `rqt_graph`.
#
# ### Topics
#
# Nodes communicate through **topics** — named channels where data flows.
#
# - A node that **sends** data to a topic is a **publisher**
# - A node that **reads** data from a topic is a **subscriber**
#
# When you ran `ros2 topic info /cmd_vel`, you saw exactly that: 1 publisher, 1 subscriber.
#
# ### Why the robot kept moving
#
# Topics are **fire and forget**. The subscriber — the robot simulator — doesn't know if the publisher is still alive. It simply executes whatever the **last message** on `/cmd_vel` was.
#
# When you pressed Ctrl+C, the publisher node disappeared — but the robot simulator already received the last velocity command and kept executing it. Nobody told it to stop.
#
# That's exactly why you need the zero velocity command to stop the robot — it sends a **new message** with `linear.x = 0`, overwriting the last one.
#
# ### Why this architecture matters
#
# - You can replace any node without touching the others
# - Multiple nodes can publish to the same topic
# - Multiple nodes can subscribe to the same topic
# - Nodes can run on different computers and still communicate
#
# This is the foundation of every robot system you will ever build.
#
# ---

# %% [markdown]
# ---
#
# ## 🔋 Live example — you are now a subscriber
#
# Run the cell below with **Shift+Enter**.
#
# This code creates a real ROS2 subscriber node in Python — the same way every ROS2 program subscribes to topics. It connects to `/battery_state` and reads the battery level every second for 10 seconds.

# %%
import os, sys
os.environ.pop('ROS_LOCALHOST_ONLY', None)
sys.stderr = open(os.devnull, 'w')
import rclpy
from rclpy.node import Node
from sensor_msgs.msg import BatteryState
if not rclpy.ok():
    rclpy.init()
sys.stderr = sys.__stderr__

import threading, time
from IPython.display import display, HTML

class BatterySubscriber(Node):
    def __init__(self):
        super().__init__('battery_subscriber')
        self.pct = None
        self.create_subscription(BatteryState, '/battery_state', self.callback, 10)

    def callback(self, msg):
        self.pct = round(msg.percentage * 100, 1)

# Clean up previous run if exists
if 'battery_node' in globals() and battery_node is not None:
    try:
        battery_executor.shutdown(timeout_sec=1)
        battery_node.destroy_node()
    except:
        pass

battery_node = BatterySubscriber()
battery_executor = rclpy.executors.SingleThreadedExecutor()
battery_executor.add_node(battery_node)
battery_thread = threading.Thread(target=battery_executor.spin, daemon=True)
battery_thread.start()

def battery_bar(pct, remaining):
    color = '#00D4FF' if pct > 50 else '#FFA500' if pct > 20 else '#FF4444'
    return f'''
<div style="font-family:monospace;background:#0a0a0a;border:1px solid #333;border-radius:8px;padding:20px;max-width:400px;">
  <div style="color:#aaa;font-size:13px;margin-bottom:8px;">🔋 /battery_state — {remaining}s remaining</div>
  <div style="background:#1a1a1a;border-radius:4px;height:24px;overflow:hidden;">
    <div style="background:{color};width:{pct}%;height:100%;"></div>
  </div>
  <div style="color:#fff;font-size:28px;font-weight:700;margin-top:8px;">{pct}%</div>
  <div style="color:#555;font-size:11px;margin-top:4px;">Live ROS2 subscriber — reading /battery_state</div>
</div>'''

ITERATIONS = 30
handle = display(HTML('<div style="color:#aaa;padding:10px;">Connecting...</div>'), display_id=True)

for i in range(ITERATIONS):
    remaining = ITERATIONS - i - 1
    if battery_node.pct is not None:
        handle.update(HTML(battery_bar(battery_node.pct, remaining)))
    else:
        handle.update(HTML('<div style="color:#FF4444;padding:10px;">⚠️ Robot not running — start start_robot.sh first</div>'))
    time.sleep(1)

handle.update(HTML('<div style="color:#aaa;font-family:monospace;padding:10px;">🔋 Monitoring stopped. Run cell again to refresh.</div>'))
battery_executor.shutdown(timeout_sec=1)
battery_node.destroy_node()

# %% [markdown]
# > You just wrote a ROS2 subscriber in 6 lines of Python. Every ROS2 program that reads sensor data does exactly this.

# %% [markdown]
# ---
#
# ## ✅ What you learned
#
# - A **node** is an independent program in a ROS2 system
# - A **topic** is a named channel for continuous data
# - A **publisher** sends data to a topic
# - A **subscriber** receives data from a topic
# - Topics are fire and forget — the subscriber acts on the last message it received
# - Nodes are decoupled — they don't need to know about each other
#
# ---
#
# ### 📋 Commands reference
#
# | Command | What it does |
# |---|---|
# | `ros2 node list` | Show all running nodes |
# | `rqt_graph` | Visualize the full node/topic graph |
# | `ros2 topic info /topic_name` | Show publishers and subscribers |
# | `ros2 topic pub --once /cmd_vel geometry_msgs/msg/Twist '{}'` | Send one velocity command |
#
# ---
#
# > Next lesson: we open the hood of the robot and discover what's really inside.
