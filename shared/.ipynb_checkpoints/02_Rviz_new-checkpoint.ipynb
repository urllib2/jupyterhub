# %% [markdown]
# # Lesson 2 — Discovering TFs with RViz
#
# *In Lesson 1 you drove a robot and observed its topics. You saw `/tf` in the topic list but didn't open it. Today we open it.*
#
# ---
#
# ## 🎬 Watch first — then do
#
# <div style="padding:56.25% 0 0 0;position:relative;">
#   <iframe src="https://player.vimeo.com/video/YOUR_VIDEO_ID"
#           style="position:absolute;top:0;left:0;width:100%;height:100%;"
#           frameborder="0" allow="autoplay; fullscreen; picture-in-picture" allowfullscreen>
#   </iframe>
# </div>
#
# ---

# %% [markdown]
# ## 🎯 What Are TFs?
#
# A **TF (Transform)** represents the spatial relationship between two coordinate frames in 3D space.
#
# TFs allow ROS2 to track how different parts of a robot are positioned and how they move over time.
#
# ---

# %% [markdown]
# ## 🚀 Launch a robot in RViz
#
# Open Terminator and run:
#
# ```bash
# ros2 launch urdf_tutorial display.launch.py model:=/opt/ros/jazzy/share/urdf_tutorial/urdf/07-physics.urdf
# ```
#
# This launches RViz with a complete robot model already loaded.
#
# Navigate in RViz using:
# - **Left-click + drag**: Rotate
# - **Right-click + drag**: Pan
# - **Mouse wheel**: Zoom
#
# ![Robot in RViz](images/page_1.png)
#
# ---

# %% [markdown]
# ## 🔗 Links, Frames, and TFs
#
# - **Link**: one rigid part of the robot
# - **Frame**: the coordinate system attached to that link
# - **TF**: the relationship between two frames — position and rotation
#
# In RViz, open **RobotModel → Links** in the left panel to show or hide individual rigid parts.
#
# ![Links and frames](images/page_2.png)
#
# ---

# %% [markdown]
# ## 🧭 Coordinate Systems — the Right-Hand Rule
#
# ROS2 uses the **right-hand rule** for all coordinate frames:
#
# <div style="display:flex;align-items:center;gap:32px;">
# <div>
#
# - **X** (red): forward
# - **Y** (green): left
# - **Z** (blue): up
#
# Every link in the robot has its own local X, Y, Z axes. When you see colored arrows in RViz, you are seeing these axes.
#
# </div>
# <img src="images/hand_right.png" style="height:180px;"/>
# </div>
#
# ![Frames in RViz](images/page_3.png)
#
# ---

# %% [markdown]
# ## 🌳 The TF Tree — parent and child frames
#
# TFs are organized as a **tree**:
# - Every frame has exactly one parent
# - A frame can have many children
# - Moving a parent moves all its children
#
# ![TF tree](images/page_4.png)
#
# ---

# %% [markdown]
# ## 📡 The /tf topic
#
# In a second terminal, run:
#
# ```bash
# ros2 topic echo /tf
# ```
#
# Each message contains:
# - Parent frame and child frame
# - Translation (x, y, z)
# - Rotation (as a quaternion)
# - Timestamp
#
# Use the joint sliders in the RViz GUI to move the robot's joints. Watch the `/tf` values change in real time.
#
# ---

# %% [markdown]
# ## 🗺️ Visualizing the TF tree
#
# In the terminal:
#
# ```bash
# cd /tmp && ros2 run tf2_tools view_frames
# evince /tmp/frames.pdf
# ```
#
# This generates a diagram showing every frame and how they connect.
#
# ![TF tree diagram](images/page_6.png)
#
# ---

# %% [markdown]
# ## ❓ Why Do We Need TFs?
#
# Every robotics system must always know:
# - Where each part is located
# - How parts move relative to each other
# - How sensor data relates to the robot body
#
# TFs solve this problem in a unified, scalable way. Every algorithm in ROS2 — navigation, manipulation, perception — reads from the TF tree.
#
# ![Why TFs](images/page_7.png)
#
# ---

# %% [markdown]
# ## 🔧 Widget — Inspect the robot's URDF
#
# The robot you launched in RViz is described by a URDF file. Run the cell below to parse it and display its full kinematic structure.

# %%
import xml.etree.ElementTree as ET
from IPython.display import display, HTML

urdf_path = '/opt/ros/jazzy/share/urdf_tutorial/urdf/07-physics.urdf'

try:
    tree = ET.parse(urdf_path)
    root = tree.getroot()
except FileNotFoundError:
    display(HTML('<div style="color:#FF4444;font-family:monospace;padding:12px;background:#1a0000;border-radius:8px;">'
                 '⚠️ File not found: ' + urdf_path + '</div>'))
    raise

# Parse links
links = {}
for link in root.findall('link'):
    name = link.get('name')
    geom_type, dims = 'virtual', ''
    visual = link.find('visual')
    if visual is not None:
        geom = visual.find('geometry')
        if geom is not None:
            for child in geom:
                geom_type = child.tag
                if child.tag == 'cylinder':
                    dims = f"r={child.get('radius')}m  l={child.get('length')}m"
                elif child.tag == 'box':
                    dims = f"size={child.get('size')}"
                elif child.tag == 'sphere':
                    dims = f"r={child.get('radius')}m"
                elif child.tag == 'mesh':
                    dims = child.get('filename', '').split('/')[-1]
    links[name] = {'geom_type': geom_type, 'dims': dims}

# Parse joints
joints = []
for joint in root.findall('joint'):
    parent = joint.find('parent').get('link')
    child  = joint.find('child').get('link')
    jtype  = joint.get('type')
    origin = joint.find('origin')
    xyz = origin.get('xyz', '0 0 0') if origin is not None else '0 0 0'
    joints.append({'name': joint.get('name'), 'type': jtype,
                   'parent': parent, 'child': child, 'xyz': xyz})

# Build tree
parent_map   = {j['child']: j for j in joints}
children_map = {}
for j in joints:
    children_map.setdefault(j['parent'], []).append(j)
root_link = next(n for n in links if n not in {j['child'] for j in joints})

jtype_color = {'fixed': '#555', 'continuous': '#00D4FF', 'revolute': '#FFA500', 'prismatic': '#00FF88', 'floating': '#FF69B4', 'planar': '#DA70D6'}
jtype_icon  = {'fixed': '🔒', 'continuous': '🔄', 'revolute': '↺', 'prismatic': '↔️', 'floating': '~', 'planar': '⬚'}

def render(link_name, depth=0, joint=None):
    indent = '&nbsp;' * (depth * 6)
    connector = '└── ' if depth > 0 else ''
    info = links.get(link_name, {})
    badge, xyz_info = '', ''
    if joint:
        color = jtype_color.get(joint['type'], '#888')
        icon  = jtype_icon.get(joint['type'], '')
        badge = f'<span style="background:{color}22;border:1px solid {color};color:{color};border-radius:4px;padding:1px 6px;font-size:11px;margin-right:6px;">{icon} {joint["type"]}</span>'
        xyz_info = f'<span style="color:#333;font-size:11px;margin-left:8px;">@ {joint["xyz"]}</span>'
    html = (f'<div style="margin:3px 0;">{indent}'
            f'<span style="color:#888;">{connector}</span>{badge}'
            f'<span style="color:#fff;font-weight:700;">{link_name}</span> '
            f'<span style="color:#555;font-size:12px;">{info["geom_type"]}</span> '
            f'<span style="color:#00D4FF;font-size:12px;">{info["dims"]}</span>'
            f'{xyz_info}</div>')
    for child_joint in children_map.get(link_name, []):
        html += render(child_joint['child'], depth + 1, child_joint)
    return html

legend = ''.join([
    f'<span style="background:{color}22;border:1px solid {color};color:{color};border-radius:4px;padding:2px 8px;font-size:12px;margin-right:8px;">'
    f'{jtype_icon.get(jt,"")} {jt}</span>'
    for jt, color in jtype_color.items()
])

display(HTML(f'''
<div style="font-family:monospace;background:#0a0a0a;border:1px solid #333;border-radius:8px;padding:24px;max-width:750px;">
  <div style="color:#aaa;font-size:13px;margin-bottom:4px;">Robot: <span style="color:#fff;">{root.get("name", "unknown")}</span></div>
  <div style="color:#aaa;font-size:13px;margin-bottom:16px;">Links: <span style="color:#fff;">{len(links)}</span> &nbsp;&nbsp; Joints: <span style="color:#fff;">{len(joints)}</span></div>
  <div style="margin-bottom:16px;">{legend}</div>
  <div style="border-top:1px solid #222;padding-top:16px;">{render(root_link)}</div>
</div>
'''))
# Out:
# <div style="font-family:monospace;background:#0a0a0a;border:1px solid #333;border-radius:8px;padding:24px;max-width:750px;">
#   <div style="color:#aaa;font-size:13px;margin-bottom:4px;">Robot: <span style="color:#fff;">physics</span></div>
#   <div style="color:#aaa;font-size:13px;margin-bottom:16px;">Links: <span style="color:#fff;">16</span> &nbsp;&nbsp; Joints: <span style="color:#fff;">15</span></div>
#   <div style="margin-bottom:16px;"><span style="background:#55522;border:1px solid #555;color:#555;border-radius:4px;padding:2px 8px;font-size:12px;margin-right:8px;">🔒 fixed</span><span style="background:#00D4FF22;border:1px solid #00D4FF;color:#00D4FF;border-radius:4px;padding:2px 8px;font-size:12px;margin-right:8px;">🔄 continuous</span><span style="background:#FFA50022;border:1px solid #FFA500;color:#FFA500;border-radius:4px;padding:2px 8px;font-size:12px;margin-right:8px;">↺ revolute</span><span style="background:#00FF8822;border:1px solid #00FF88;color:#00FF88;border-radius:4px;padding:2px 8px;font-size:12px;margin-right:8px;">↔️ prismatic</span><span style="background:#FF69B422;border:1px solid #FF69B4;color:#FF69B4;border-radius:4px;padding:2px 8px;font-size:12px;margin-right:8px;">~ floating</span><span style="background:#DA70D622;border:1px solid #DA70D6;color:#DA70D6;border-radius:4px;padding:2px 8px;font-size:12px;margin-right:8px;">⬚ planar</span></div>
#   <div style="border-top:1px solid #222;padding-top:16px;"><div style="margin:3px 0;"><span style="color:#888;"></span><span style="color:#fff;font-weight:700;">base_link</span> <span style="color:#555;font-size:12px;">cylinder</span> <span style="color:#00D4FF;font-size:12px;">r=0.2m  l=0.6m</span></div><div style="margin:3px 0;">&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;<span style="color:#888;">└── </span><span style="background:#55522;border:1px solid #555;color:#555;border-radius:4px;padding:1px 6px;font-size:11px;margin-right:6px;">🔒 fixed</span><span style="color:#fff;font-weight:700;">right_leg</span> <span style="color:#555;font-size:12px;">box</span> <span style="color:#00D4FF;font-size:12px;">size=0.6 0.1 0.2</span><span style="color:#333;font-size:11px;margin-left:8px;">@ 0 -0.22 0.25</span></div><div style="margin:3px 0;">&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;<span style="color:#888;">└── </span><span style="background:#55522;border:1px solid #555;color:#555;border-radius:4px;padding:1px 6px;font-size:11px;margin-right:6px;">🔒 fixed</span><span style="color:#fff;font-weight:700;">right_base</span> <span style="color:#555;font-size:12px;">box</span> <span style="color:#00D4FF;font-size:12px;">size=0.4 0.1 0.1</span><span style="color:#333;font-size:11px;margin-left:8px;">@ 0 0 -0.6</span></div><div style="margin:3px 0;">&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;<span style="color:#888;">└── </span><span style="background:#00D4FF22;border:1px solid #00D4FF;color:#00D4FF;border-radius:4px;padding:1px 6px;font-size:11px;margin-right:6px;">🔄 continuous</span><span style="color:#fff;font-weight:700;">right_front_wheel</span> <span style="color:#555;font-size:12px;">cylinder</span> <span style="color:#00D4FF;font-size:12px;">r=0.035m  l=0.1m</span><span style="color:#333;font-size:11px;margin-left:8px;">@ 0.133333333333 0 -0.085</span></div><div style="margin:3px 0;">&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;<span style="color:#888;">└── </span><span style="background:#00D4FF22;border:1px solid #00D4FF;color:#00D4FF;border-radius:4px;padding:1px 6px;font-size:11px;margin-right:6px;">🔄 continuous</span><span style="color:#fff;font-weight:700;">right_back_wheel</span> <span style="color:#555;font-size:12px;">cylinder</span> <span style="color:#00D4FF;font-size:12px;">r=0.035m  l=0.1m</span><span style="color:#333;font-size:11px;margin-left:8px;">@ -0.133333333333 0 -0.085</span></div><div style="margin:3px 0;">&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;<span style="color:#888;">└── </span><span style="background:#55522;border:1px solid #555;color:#555;border-radius:4px;padding:1px 6px;font-size:11px;margin-right:6px;">🔒 fixed</span><span style="color:#fff;font-weight:700;">left_leg</span> <span style="color:#555;font-size:12px;">box</span> <span style="color:#00D4FF;font-size:12px;">size=0.6 0.1 0.2</span><span style="color:#333;font-size:11px;margin-left:8px;">@ 0 0.22 0.25</span></div><div style="margin:3px 0;">&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;<span style="color:#888;">└── </span><span style="background:#55522;border:1px solid #555;color:#555;border-radius:4px;padding:1px 6px;font-size:11px;margin-right:6px;">🔒 fixed</span><span style="color:#fff;font-weight:700;">left_base</span> <span style="color:#555;font-size:12px;">box</span> <span style="color:#00D4FF;font-size:12px;">size=0.4 0.1 0.1</span><span style="color:#333;font-size:11px;margin-left:8px;">@ 0 0 -0.6</span></div><div style="margin:3px 0;">&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;<span style="color:#888;">└── </span><span style="background:#00D4FF22;border:1px solid #00D4FF;color:#00D4FF;border-radius:4px;padding:1px 6px;font-size:11px;margin-right:6px;">🔄 continuous</span><span style="color:#fff;font-we ...

# %% [markdown]
# ---
#
# ## 🧠 Challenge — Explore the tree
#
# Look at the widget output above and answer these questions:
#
# 1. What is the **root link** — the one at the top of the tree with no parent?
# 2. How many **continuous** joints does this robot have? What parts of the robot do they correspond to?
#
# *Write your answers here:*

# %% [markdown]
# **1. Root link:**
#
# **2. Continuous joints:**

# %% [markdown]
# ---
#
# ## ✅ What you learned
#
# - A **link** is a rigid part of the robot — chassis, wheel, arm segment
# - A **frame** is the coordinate system attached to each link
# - A **TF** is the relationship between two frames — position and rotation
# - TFs are organized as a **tree** — moving a parent moves all its children
# - The `/tf` topic carries these relationships in real time
# - `view_frames` generates a diagram of the full tree
#
# ---
#
# ### 📋 Commands reference
#
# | Command | What it does |
# |---|---|
# | `ros2 launch urdf_tutorial display.launch.py model:=<file>` | Launch a robot in RViz |
# | `ros2 topic echo /tf` | See coordinate frame transforms in real time |
# | `ros2 run tf2_tools view_frames` | Generate a diagram of the full TF tree |
#
# ---
#
# > You explored a robot that someone else designed. You read its structure, counted its joints, traced its tree.
# >
# > In the next lesson you will build one yourself — link by link, joint by joint — until you have a complete differential drive robot.
# >
# > **Next lesson: build your own robot.**
