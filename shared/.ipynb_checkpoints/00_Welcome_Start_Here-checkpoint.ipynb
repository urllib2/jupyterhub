# %% [markdown]
# # 🎉 Welcome to ROS2 Robotics Course!
#
# ## Hello! 👋
#
# Welcome to your hands-on ROS2 learning platform. You're about to learn robotics by **doing**, not just watching!
#
# ---
#
# ## 🗂️ Your Workspace Overview
#
# You have **three folders** in the sidebar:
#
# ### 📖 `course_materials/` (You are here!)
# - **Read-only** course content
# - Video tutorials and lessons
# - All course notebooks
# - **Browse, but don't save here!**
#
# ### 💻 `ros2_ws/` (Your Personal Workspace)
# - **This is YOUR space** - save all your work here!
# - Create Python scripts
# - Save challenge solutions
# - Your files persist forever
#
# ### 🗑️ `temporary_ws/` (Scratch Space)
# - Temporary experiments
# - **Files here are deleted** when you log out
# - Use for quick tests only
#
# ---
#
# ## 🎬 How Each Lesson Works
#
# Every lesson follows this simple pattern:
#
# 1. **📺 Watch** - Short 5-minute video on Vimeo
# 2. **👀 Read** - Follow along in the notebook
# 3. **🖥️ Try** - Run commands in the Desktop terminal
# 4. **💾 Save** - Save your solutions in `ros2_ws/`
#
# ---
#
# ## 🖥️ Accessing Your Desktop
#
# You have a **full Linux desktop** with ROS2 installed!
#
# ### Click the button below to open your desktop:

# %%
# Desktop Access - Secure VNC through JupyterHub proxy
import os
from IPython.display import HTML, display

# Get current user dynamically
user = os.environ.get('JUPYTERHUB_USER') or os.environ.get('USER', 'user')

# Use JupyterHub's secure proxy to access noVNC
desktop_url = f"https://app.rosforge.com/user/{user}/proxy/6080/"

html_content = f"""
<div style="background: linear-gradient(135deg, #667eea 0%, #764ba2 100%); color: white; padding: 25px; border-radius: 15px; margin: 20px 0; box-shadow: 0 8px 20px rgba(0,0,0,0.2);">
    <h2 style="margin: 0 0 20px 0; text-align: center;">🖥️ Your ROS2 Desktop Environment</h2>
    
    <div style="background: rgba(255,255,255,0.1); padding: 15px; border-radius: 8px; margin-bottom: 20px;">
        <h3 style="margin-top: 0;">✅ Desktop Status: Ready</h3>
        <p style="margin: 5px 0;">🟢 Display Server: Running</p>
        <p style="margin: 5px 0;">🟢 VNC Interface: Available</p>
        <p style="margin: 5px 0;">🔒 Authentication: Protected</p>
    </div>
    
    <div style="text-align: center;">
        <a href="{desktop_url}" target="_blank" 
           style="background: #4CAF50; color: white; padding: 20px 40px; text-decoration: none; border-radius: 10px; font-size: 20px; font-weight: bold; display: inline-block; margin: 10px; box-shadow: 0 4px 15px rgba(0,0,0,0.3); transition: transform 0.2s;"
           onmouseover="this.style.transform='scale(1.05)'; this.style.background='#45a049';"
           onmouseout="this.style.transform='scale(1)'; this.style.background='#4CAF50';">
            🚀 Open Desktop in New Tab
        </a>
    </div>
    
    <div style="background: rgba(255,255,255,0.1); padding: 15px; border-radius: 8px; margin-top: 20px; font-size: 14px;">
        <h4 style="margin-top: 0;">📋 Quick Start Instructions:</h4>
        <ol style="margin: 10px 0; padding-left: 20px;">
            <li>Click the green button above</li>
            <li>Wait for desktop to load (~5 seconds)</li>
            <li><strong>Right-click</strong> anywhere on the desktop</li>
            <li>Select <strong>"Terminator"</strong> to open terminal</li>
            <li>Start coding! 🎉</li>
        </ol>
    </div>
</div>
"""

display(HTML(html_content))

print("\n🎮 Available GUI Applications:")
print("  • Terminator - Terminal with large font (recommended!)")
print("  • XTerm - Simple terminal")
print("  • RViz2 - 3D robot visualization")
print("  • TurtleSim - Learning simulator")
print("  • RQT - ROS debugging tools")

# %% [markdown]
# ---
#
# ## 🚀 Quick Start Test
#
# Let's verify ROS2 is working!
#
# ### Step 1: Open Your Desktop
# Click the green button above ☝️
#
# ### Step 2: Open Terminator
# On the desktop:
# - **Right-click** anywhere
# - Select **"Terminator"** (it has a large, readable font!)
#
# ### Step 3: Test ROS2
# In the terminal, type:
# ```bash
# ros2 topic list
# ```
#
# You should see:
# ```
# /rosout
# ```
#
# **✅ Success!** ROS2 is ready!
#
# ---
#
# ## 🐢 Your First Robot: Turtlesim!
#
# Let's run your first ROS2 program!
#
# ### In your Terminator terminal:
# ```bash
# ros2 run turtlesim turtlesim_node
# ```
#
# You should see a blue window with a cute turtle! 🐢
#
# ### Want to drive it?
#
# **Open a second terminal:**
# - In Terminator: **Right-click** → **Split Horizontally**
#
# **In the new terminal:**
# ```bash
# ros2 run turtlesim turtle_teleop_key
# ```
#
# **Use arrow keys to drive!** ⬆️⬇️⬅️➡️
#
# ---
#
# ## 📚 Course Structure
#
# ### Week 1: ROS2 Fundamentals
# - Introduction to ROS2 concepts
# - Turtlesim exploration
# - Topics, nodes, and messages
# - Writing your first Python ROS2 code
#
# ### Week 2: Robot Description & Visualization
# - URDF robot models
# - Robot state publisher
# - Visualizing robots in RViz2
# - Creating custom robot descriptions
#
# ### Week 3: Coordinate Transformations
# - TF2 transformation system
# - Coordinate frames
# - Real robot coordinate systems
# - Practical applications
#
# ---
#
# ## 💡 Important Tips
#
# ### ✅ DO:
# - **Save all work in `ros2_ws/` folder** - it's persistent!
# - **Watch videos first** - they're only 5 minutes
# - **Try everything** - you can't break anything
# - **Use Terminator** - better font and split terminals
# - **Take breaks** - your session stays active for 30 minutes
#
# ### ❌ DON'T:
# - Don't save in `course_materials/` - it's read-only
# - Don't save in `temporary_ws/` - files are deleted on logout
# - Don't worry about making mistakes - experiment freely!
#
# ---
#
# ## 🎓 Ready to Start Learning?
#
# ### 👉 Next Lesson:
# **[01_Desktop_Access.ipynb](./01_Desktop_Access.ipynb)** - Deep dive into the desktop environment
#
# ### Or jump to:
# - **[Week_01/](./Week_01/)** - Start the structured course
#
# ---
#
# ## Let's Build Robots! 🤖
#
# <div style="background: #e8f5e9; padding: 20px; border-radius: 10px; border-left: 5px solid #4CAF50; margin-top: 30px;">
#     <h3 style="margin-top: 0; color: #2e7d32;">🎯 Remember</h3>
#     <p style="color: #333; font-size: 16px;">
#         <strong>Save all your work in the <code>ros2_ws/</code> folder!</strong><br>
#         This is the ONLY place where your files persist between sessions.
#     </p>
# </div>
